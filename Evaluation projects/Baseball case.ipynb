# %%
"""
Dataset Exploratory data analysis AND FURTHUR STEPS:

Elementary exploration and definitions:

1.Dataset contains 30 rows and 17 columns including target label i.e. 'W'. Fullform and brief explaination is given below:

'W': wins
'R' : R – Runs scored: times reached home plate legally and safely
'AB' : AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
'H': Hit: reaching base because of a batted, fair ball without error by the defense
'2B' : Doubles
'3B' : Triples
'HR' : Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
'BB' : Base on ball
'SO': Strikeouts
'SB': Stolen Bases
'RA': Runs Allowed
'ER' : Earned Runs
'ERA' : Earned Run Average (ERA)
'CG' : Complete Games
'SHO' : Shutouts
'SV' : Saves
'E' : Errors

Count of rows and columns represent dataset is small with less features and entries which might result in overfitting of data.
We need to be careful while we train our model.

2. No null values can be found in dataset.

3. We have all numerical data types in dataset.

4. Descriptive statistics:
    1. Each column contains 30 entries/rows.
    2. Mean, Standard deviation and range of values seem fine.
    3. Central tendency and dispersion of each column is shared below:
    
              mean           std
        W	80.966667	10.453455
        R	688.233333	58.761754
        AB	5516.266667	70.467372
        H	1403.533333	57.140923
        2B	274.733333	18.095405
        3B	31.300000	10.452355
        HR	163.633333	31.823309
        BB	469.100000	57.053725
        SO	1248.200000	103.759470
        SB	83.500000	22.815225
        RA	688.233333	72.108005
        ER	635.833333	70.140786
        ERA	3.956333	0.454089
        CG	3.466667	2.763473
        SHO	11.300000	4.120177
        SV	43.066667	7.869335
        E	94.333333	13.958889

5. Lets create some new features 
    AB/HR – At bats per home run: at bats divided by home runs
    BB/SO: Walk-to-strikeout ratio: number of bases on balls divided by number of strikeouts
    home runs divided by total hits

6. There is no duplicate value in dataset.

7. As wins is our target variable and highest value of Wins is "100", noting values of features when Win is highest.

Highest Wins occur when SV is 62
Highest Wins occur when SHO is 15
Highest Wins occur when CG is 1
Highest Wins occur when ERA is 2.940000
Highest Wins occur when RA is 525
Highest Wins occur when SB is 69
Highest Wins occur when So is 1267
Highest Wins occur when BB is 506
Highest Wins occur when HR is 137
Highest Wins occur when R is 647
Highest Wins occur when H is 1386.000000
Highest Wins occur when AB is 5484.000000
Highest Wins occur when ER is 478.0

8. Statistical analysis of features:

a) Univariate Analysis:

Frequency interval ranges where values occur are mentioned below:
    For W, interval range 80 to 100.
    for R , range ia 600 to 750
    AB values are randomly distributed.
    H values range 1325 to 1400
    2B values are randomly distributed.
    3B values are  randomly distributed.
    HR values are Frequency btw range btw 120 to 180
    BB values are randomly distributed.
    SO values are Frequency btw range btw 1100 to 1350
    SB values are randomly distributed.
    RA values are Frequency btw range btw 580 to 760
    ER values are Frequency btw range btw 540 to 700
    ERA values are Frequency btw range btw 3.4 to 4.5
    CG values are randomly distributed.
    SHO values are randomly distributed.
    SV values are ranged between 33 to 47
    E values are ranged between 33 to 47

Density interval ranges where values occur are mentioned below:
    For W, interval range 50 to 110.
    for R , range ia 550 to 800
    AB values are btw 5300 to 5700
    H values range 1250 to 1550
    2B values are btw 220 to 320.
    3B values are  10 to 55.
    HR values are Density btw range btw 100 to 250
    BB values are 300 to 650..
    SO values are Density btw range btw 1000 to 1500
    SB values are btw 20 to 160.
    RA values are Density btw range btw 550 to 900
    ER values are Density btw range btw 540 to 700
    ERA values are Density btw range btw 3.4 to 4.5
    CG values are randomly distributed.
    SHO values are randomly distributed.
    SV values are ranged between 33 to 47
    E values are ranged between 33 to 47
    
Bivariate analysis:
    
Using scatterplot we can conclude that: 
    
    Columns whose points are randomly scattered and no confirm relation can be established: 
        'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ER',
        'ERA', 'CG', 'E'
      
    Columns that confirm some relation can be established with label: 
    'R', 'HR/H','BB/SO','SV','SHO','RA'
    
    Lineplot also confirms the same relationship trend with the label variable. As and when values of 
    {'R', 'HR/H','BB/SO','SV','SHO','RA'} these features change, a direct change can be seen in target label variable.
    
    Strip plot can be used to note down the number of data points that lie at particular value of all the features.
    
Using regression plot to check upward trend or downward trend between label and features:
    
    R, 2B, HR, BB, SO, SHO, SV, features show a direct relationship with wins label.
    
    AB , H, 3B, SB, CG, E features show a neutral relationship with wins label.
    
    RA, ER, ERA features show an indirect relationship with wins label.

Conclusions from pairplot:
    Points noted from previous graph comply to the relationship between features and labels shown in pairplot.
    A strong corelation can be seen between new created features and AB,H,Hr values as they have been derived by
    using these values.
    
Distribution plot to check skewness within data:

Density distribution graph more or less tells data is not skewed or probably might contain very less outliers.

Using outlier detection method:
    
    Using boxplot to detect outliers R, SHO, SV, E, AB/HR contain outliers.
    
    Checking data skewness we can see that most of column values are within permissible limits.
    
    But, As our dataset is small, removing outliers might result in losing potential data.
    
    We will use Zscore technique to remove a few outlier and values lying in 3 times std will be removed.
    
Checking heatmaps and correlation between features and labels:
    
    From heatmap RA,ER,RA,SV,SHO can be found to be highly correlated.
    We can see that, multicollinearity problem exists between multiple columns and we need to get rid of these features
    resulting in multicollinearity.
    
    'ERA','ER','RA' are removed from set of potential features and furthur after checking variance inflation factor 
    we can conclude that we have got rid of multicollinearity problem and now we can proceed with model evaluation.
    
Using Principal component analysis and scree plot we can confirm that we are left with 12 most important components or
features reponsible for predicting Wins value.

# Model instantiation and training:

After checking different models we can see that best result is obtained by using Linear regression and lasso regularization
technique.

# Sharing results found using Lasso regression model:

MAE:  4.740517672182099
MSE:  38.15445557317316
RMSE:  6.176929299674164
R2:  0.6537315432950819 

Score:  1.0

CHECKLIST:
NULLS REMOVED
DUPLICATES REMOVED.
HISTOGRAM PLOT
SCATTERPLOT
LINE PLOT
PAIRPLOT 
BOXPLOT
DISTRIBUTION PLOT
HEATMAP
CORRELATION CHECKED, vif FOUND
MULTICOLLINEARITY REMOVED USING PCA
DATA SCALING DONE
MODELS USED:
    LINEAR REGRESSION
    RIDGE , LASSO
    DECISION TREE
    RANDOM FORREST
    SUPPORT VECTOR MACHINE
    KNN
    ADABOOST
    XGBOOST
CROSS VALIDATION DONE
PIPELINE CREATED


"""
# Out:
# '\nDataset Exploratory data analysis AND FURTHUR STEPS:\n\nElementary exploration and definitions:\n\n1.Dataset contains 30 rows and 17 columns including target label i.e. \'W\'. Fullform and brief explaination is given below:\n\n\'W\': wins\n\'R\' : R – Runs scored: times reached home plate legally and safely\n\'AB\' : AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction\n\'H\': Hit: reaching base because of a batted, fair ball without error by the defense\n\'2B\' : Doubles\n\'3B\' : Triples\n\'HR\' : Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error\n\'BB\' : Base on ball\n\'SO\': Strikeouts\n\'SB\': Stolen Bases\n\'RA\': Runs Allowed\n\'ER\' : Earned Runs\n\'ERA\' : Earned Run Average (ERA)\n\'CG\' : Complete Games\n\'SHO\' : Shutouts\n\'SV\' : Saves\n\'E\' : Errors\n\nCount of rows and columns represent dataset is small with less features and e
# ...

# %%
# Imp libs:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Standardizing and Normalizing data:
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
import xgboost as xgb

# Spliting data
from sklearn.model_selection import train_test_split,GridSearchCV

# Importing metrics
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error

# Removing warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
file_loc = 'https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv'
df = pd.read_csv(file_loc)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
desc = df.describe().T
df.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
desc.columns
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
desc['Range'] = desc['max']-desc['min']

# %%
desc
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
desc[['mean','std','Range']]
# Out:
#             mean         std  Range
# W      80.966667   10.453455   37.0
# R     688.233333   58.761754  318.0
# AB   5516.266667   70.467372  264.0
# H    1403.533333   57.140923  191.0
# 2B    274.733333   18.095405   72.0
# 3B     31.300000   10.452355   36.0
# HR    163.633333   31.823309  132.0
# BB    469.100000   57.053725  195.0
# SO   1248.200000  103.759470  545.0
# SB     83.500000   22.815225   90.0
# RA    688.233333   72.108005  319.0
# ER    635.833333   70.140786  321.0
# ERA     3.956333    0.454089    2.1
# CG      3.466667    2.763473   11.0
# SHO    11.300000    4.120177   17.0
# SV     43.066667    7.869335   34.0
# E      94.333333   13.958889   51.0

# %%
# Creating new features:

"""AB/HR – At bats per home run: at bats divided by home runs"""
df['AB/HR'] = df['AB']/df['HR']

"""BB/SO: Walk-to-strikeout ratio: number of bases on balls divided by number of strikeouts"""
df['BB/SO'] = df['BB']/df['SO']

"""home runs divided by total hits"""
df['HR/H'] = df['HR']/df['H']

# %%
df = df[['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E','AB/HR','BB/SO','HR/H']]

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E      AB/HR     BB/SO      HR/H
# 0  56   88  40.107914  0.393628  0.092852
# 1  45   86  35.044872  0.347310  0.115641
# 2  38   79  38.574468  0.460674  0.101075
# 3  37  101  40.683824  0.328188  0.098479
# 4  35   86  37.119205  0.361398  0.099670

# %%
features = df.drop(columns = ['W'],axis=1)
features.columns
target = df.W

# %%
features.shape[1]
# Out:
# 19

# %%
#checking for duplicates:

df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
df.groupby(by="W").SV.mean().to_frame()
# Out:
#             SV
# W
# 63   35.000000
# 64   35.000000
# 67   44.000000
# 68   34.666667
# 71   35.000000
# 74   38.000000
# 76   41.000000
# 78   40.000000
# 79   44.000000
# 80   60.000000
# 81   40.500000
# 83   43.000000
# 84   41.000000
# 85   46.000000
# 86   39.000000
# 87   48.000000
# 88   45.000000
# 90   50.000000
# 92   47.000000
# 93   34.000000
# 95   56.000000
# 97   48.000000
# 98   54.000000
# 100  62.000000

# %%
df.groupby(by="W").SHO.mean().to_frame()
# Out:
#            SHO
# W
# 63    7.000000
# 64    8.000000
# 67   10.000000
# 68    8.666667
# 71   12.000000
# 74    9.000000
# 76   10.500000
# 78   10.000000
# 79   12.000000
# 80   12.000000
# 81   10.000000
# 83   12.500000
# 84   18.000000
# 85   12.000000
# 86   13.000000
# 87    4.000000
# 88    9.000000
# 90   14.000000
# 92   21.000000
# 93   10.000000
# 95    8.000000
# 97   21.000000
# 98   13.000000
# 100  15.000000

# %%
df.groupby(by="W").CG.mean().to_frame()
# Out:
#            CG
# W
# 63   1.000000
# 64   2.000000
# 67   3.000000
# 68   3.333333
# 71   0.000000
# 74   4.000000
# 76   6.500000
# 78   3.000000
# 79   1.000000
# 80   1.000000
# 81   5.500000
# 83   3.000000
# 84   7.000000
# 85   2.000000
# 86   5.000000
# 87   3.000000
# 88   5.000000
# 90   1.000000
# 92   6.000000
# 93   7.000000
# 95   2.000000
# 97   6.000000
# 98   0.000000
# 100  1.000000

# %%
df.groupby(by="W").ERA.mean().to_frame()
# Out:
#           ERA
# W
# 63   4.690000
# 64   4.330000
# 67   4.410000
# 68   4.486667
# 71   4.020000
# 74   4.365000
# 76   4.070000
# 78   4.310000
# 79   4.040000
# 80   3.740000
# 81   3.860000
# 83   3.845000
# 84   3.720000
# 85   3.940000
# 86   3.570000
# 87   4.030000
# 88   4.240000
# 90   3.430000
# 92   3.440000
# 93   3.800000
# 95   3.730000
# 97   3.360000
# 98   3.210000
# 100  2.940000

# %%
df.groupby(by="W").RA.mean().to_frame()
# Out:
#         RA
# W
# 63   809.0
# 64   754.0
# 67   760.0
# 68   770.0
# 71   678.0
# 74   767.0
# 76   713.5
# 78   753.0
# 79   713.0
# 80   642.0
# 81   666.5
# 83   667.5
# 84   627.0
# 85   675.0
# 86   618.0
# 87   698.0
# 88   733.0
# 90   613.0
# 92   595.0
# 93   670.0
# 95   641.0
# 97   608.0
# 98   596.0
# 100  525.0

# %%
df.groupby(by="W").SB.mean().to_frame()
# Out:
#              SB
# W
# 63    88.000000
# 64   134.000000
# 67    69.000000
# 68    86.333333
# 71   112.000000
# 74    82.500000
# 76    68.500000
# 78    71.000000
# 79   132.000000
# 80    87.000000
# 81    65.000000
# 83    63.500000
# 84    93.000000
# 85    52.000000
# 86   121.000000
# 87    63.000000
# 88   101.000000
# 90    51.000000
# 92    59.000000
# 93    88.000000
# 95   104.000000
# 97    95.000000
# 98    98.000000
# 100   69.000000

# %%
df.groupby(by="W").SO.mean().to_frame()
# Out:
#               SO
# W
# 63   1274.000000
# 64   1255.000000
# 67   1107.000000
# 68   1233.666667
# 71   1150.000000
# 74   1293.000000
# 76   1283.500000
# 78   1148.000000
# 79   1312.000000
# 80   1310.000000
# 81   1244.000000
# 83   1304.000000
# 84   1159.000000
# 85   1150.000000
# 86   1392.000000
# 87   1227.000000
# 88   1233.000000
# 90   1290.000000
# 92   1258.000000
# 93   1151.000000
# 95    973.000000
# 97   1518.000000
# 98   1322.000000
# 100  1267.000000

# %%
df.groupby(by="W").BB.mean().to_frame()
# Out:
#         BB
# W
# 63   387.0
# 64   496.0
# 67   471.0
# 68   425.0
# 71   375.0
# 74   440.5
# 76   441.0
# 78   478.0
# 79   490.0
# 80   436.0
# 81   475.5
# 83   489.0
# 84   457.0
# 85   435.0
# 86   486.0
# 87   554.0
# 88   503.0
# 90   488.0
# 92   563.0
# 93   570.0
# 95   383.0
# 97   567.0
# 98   461.0
# 100  506.0

# %%
df.groupby(by="W").HR.mean().to_frame()
# Out:
#         HR
# W
# 63   130.0
# 64   167.0
# 67   100.0
# 68   159.0
# 71   120.0
# 74   149.5
# 76   167.0
# 78   161.0
# 79   154.0
# 80   167.0
# 81   179.0
# 83   166.5
# 84   136.0
# 85   176.0
# 86   230.0
# 87   212.0
# 88   172.0
# 90   177.0
# 92   187.0
# 93   232.0
# 95   139.0
# 97   171.0
# 98   140.0
# 100  137.0

# %%
df.groupby(by="W").R.mean().to_frame()
# Out:
#               R
# W
# 63   626.000000
# 64   640.000000
# 67   573.000000
# 68   695.333333
# 71   613.000000
# 74   669.500000
# 76   639.000000
# 78   748.000000
# 79   720.000000
# 80   644.000000
# 81   691.000000
# 83   699.500000
# 84   696.000000
# 85   661.000000
# 86   729.000000
# 87   764.000000
# 88   751.000000
# 90   683.000000
# 92   667.000000
# 93   891.000000
# 95   724.000000
# 97   689.000000
# 98   697.000000
# 100  647.000000

# %%
df.groupby(by="W").H.mean().to_frame()
# Out:
#                H
# W
# 63   1374.000000
# 64   1382.000000
# 67   1361.000000
# 68   1420.666667
# 71   1420.000000
# 74   1419.500000
# 76   1380.000000
# 78   1495.000000
# 79   1494.000000
# 80   1383.000000
# 81   1382.500000
# 83   1356.000000
# 84   1486.000000
# 85   1331.000000
# 86   1363.000000
# 87   1397.000000
# 88   1419.000000
# 90   1351.000000
# 92   1346.000000
# 93   1480.000000
# 95   1497.000000
# 97   1341.000000
# 98   1462.000000
# 100  1386.000000

# %%
df.groupby(by="W").AB.mean().to_frame()
# Out:
#               AB
# W
# 63   5529.000000
# 64   5571.000000
# 67   5420.000000
# 68   5550.666667
# 71   5463.000000
# 74   5531.000000
# 76   5538.500000
# 78   5640.000000
# 79   5649.000000
# 80   5485.000000
# 81   5462.000000
# 83   5447.500000
# 84   5565.000000
# 85   5417.000000
# 86   5459.000000
# 87   5567.000000
# 88   5511.000000
# 90   5527.000000
# 92   5385.000000
# 93   5509.000000
# 95   5575.000000
# 97   5491.000000
# 98   5631.000000
# 100  5484.000000

# %%
df.groupby(by="W").ER.mean().to_frame()
# Out:
#         ER
# W
# 63   749.0
# 64   700.0
# 67   698.0
# 68   715.0
# 71   638.0
# 74   700.5
# 76   660.0
# 78   694.0
# 79   659.0
# 80   604.0
# 81   615.0
# 83   615.0
# 84   597.0
# 85   630.0
# 86   572.0
# 87   652.0
# 88   680.0
# 90   557.0
# 92   553.0
# 93   609.0
# 95   601.0
# 97   546.0
# 98   532.0
# 100  478.0

# %%
# Univariate analysis 

# Histogram plot:

for i in df.columns:
    plt.figure(figsize=(10,6),facecolor='orange')
    plt.hist(df[i],bins=30)
    plt.xlabel(i)
    plt.show()

# %%
# Density plots:

for i in df.columns:
    plt.figure(figsize=(10,6),facecolor='orange')
    sns.kdeplot(df[i],shade=True)
    plt.xlabel(i)
    plt.show()

# %%
# Swarm plots:

for i in df.columns:
    plt.figure(figsize=(10,6),facecolor='orange')
    sns.swarmplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
# Finding relationship i.e. every feature vs label:

plt.figure(figsize=(20,15),facecolor='red')
plotnumber = 1

for column in features.columns:
    if plotnumber <= 19:
        ax = plt.subplot(5,4,plotnumber)
        plt.scatter(df[column],target)
        plt.xlabel(column,fontsize = 28)
        plt.ylabel('Wins',fontsize = 28)
        
    plotnumber +=1
plt.tight_layout() # plt.show() can be used

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E', 'AB/HR', 'BB/SO', 'HR/H'],
#       dtype='object')

# %%
# Finding relationship i.e. every feature vs label using line plot:

plt.figure(figsize=(20,15),facecolor='red')
plotnumber = 1

for column in features.columns:
    if plotnumber <= 19:
        ax = plt.subplot(5,4,plotnumber)
        sns.lineplot(df[column],target)
        plt.xlabel(column,fontsize = 28)
        plt.ylabel('Wins',fontsize = 28)
        
    plotnumber +=1
plt.tight_layout() # plt.show() can be used

# %%
# Using stripplot to get more insights

for column in features.columns:
    plt.figure(figsize=(20,15),facecolor='red')
    sns.stripplot(df[column],target)
    plt.xlabel(column)
    plt.ylabel('Wins')
    plt.show()

# %%
# Checking regression line to get more insights

for column in features.columns:
    plt.figure(figsize=(20,15),facecolor='red')
    sns.lmplot(x = column, y = "W", data=df, palette='Set2', height=8, aspect=1.2)
    plt.xlabel(column)
    plt.ylabel('Wins')
    plt.show()

# %%
least_related_columns = ['ERA','ER','RA']

# %%
sns.pairplot(df)

# %%
# Checking the distribution of continuous variables:

plt.figure(figsize=(20,15),facecolor='Yellow')
plotnumber = 1
for column in df.columns:
    if plotnumber <= 19:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber += 1
plt.show()

# %%
# Lets remove outliers and check the score:

plt.figure(figsize=(20,25),facecolor='Yellow')
plotnumber = 1
for col in df.columns:
    if plotnumber <= 19:
        ax = plt.subplot(5,4,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnumber += 1
plt.show()

# %%
df.skew().sort_values()
# Out:
# 2B      -0.230650
# SO      -0.156065
# RA       0.045734
# W        0.047089
# ERA      0.053331
# ER       0.058710
# 3B       0.129502
# BB       0.158498
# AB       0.183437
# BB/SO    0.408965
# HR/H     0.460225
# SB       0.479893
# AB/HR    0.515088
# HR       0.516441
# SHO      0.565790
# SV       0.657524
# H        0.670254
# CG       0.736845
# E        0.890132
# R        1.200786
# dtype: float64

# %%
file_loc = 'https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv'
df = pd.read_csv(file_loc)

# %%
cols = df.columns

# %%
"""# Using Z Statistics to check and remove any more outliers:

from scipy.stats import zscore

z_score = zscore(df[cols])

abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 3).all(axis=1) # values lying in 3 times std will be removed

df = df[filtering_entry]

df.describe()"""
# Out:
# '# Using Z Statistics to check and remove any more outliers:\n\nfrom scipy.stats import zscore\n\nz_score = zscore(df[cols])\n\nabs_z_score = np.abs(z_score)\n\nfiltering_entry = (abs_z_score < 3).all(axis=1) # values lying in 3 times std will be removed\n\ndf = df[filtering_entry]\n\ndf.describe()'

# %%
# no outliers removed

# %%
# Correlation between features and label:

df.drop(columns = 'W',axis = 1).corrwith(df.W).plot(kind='bar',grid=True,figsize=(10,7),title='corelation between features and labels')
plt.show()

# %%
# Using heatmap to check correlation:

df_corr = df.corr().abs()
plt.figure(figsize=(18,14))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(df[cols],i) for i in range(df[cols].shape[1])]
vif['features'] = df[cols].columns
vif

# These number indicate that if vif value < 5 , 
# no multicolinearity problem exist
# Out:
#              vif features
# 0    1164.543214        W
# 1    3253.807721        R
# 2    5181.779465       AB
# 3    4817.334228        H
# 4    1157.105781       2B
# 5      32.435486       3B
# 6     309.301103       HR
# 7     302.099558       BB
# 8     400.292880       SO
# 9      28.665516       SB
# 10  18170.014649       RA
# 11  51175.790270       ER
# 12  23668.747242      ERA
# 13     10.411616       CG
# 14     33.258426      SHO
# 15    331.282416       SV
# 16     96.958680        E

# %%
df.drop(columns=least_related_columns,inplace=True,axis=1)

# %%
"we can observe that multicolinearity problem exist"
# Out:
# 'we can observe that multicolinearity problem exist'

# %%
# Splitting data into features and label:

y = df['W']
X = df.drop('W',axis=1)

# %%
# Standardizing data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# transform data
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[ 0.61907797  0.84773126  1.66368512  1.42017307  1.04119304 -0.7872986
#   -1.53490242 -2.69762957  0.91388329 -0.5398062  -0.81462859  1.67160651
#   -0.46146963]
#  [ 0.13443166 -0.71109353 -0.97068076  0.12740339  1.23580856 -0.24396668
#   -0.5365919   0.15487844 -0.60182558 -0.5398062   0.1728      0.24987932
#   -0.60719689]
#  [-0.33290586 -1.1152333  -0.15189137  1.58879521 -0.22380785 -0.7233772
#    1.13914361 -0.89398189  0.11144918  2.77264091 -0.32091429 -0.65485616
#   -1.11724227]
#  [-1.14641931  0.24152162 -0.40108814 -0.82812203 -0.41842337 -0.8831807
#   -1.16053598 -0.16860185 -0.69098493  1.3004422  -0.56777144 -0.78410408
#    0.48575751]
#  [ 0.01327008  1.28073815  1.98408098  0.80189192  1.72234737 -0.40377019
#   -0.25136033  0.10586628 -0.02228984  1.3004422   0.1728     -1.04259994
#   -0.60719689]
#  [ 3.50964704 -0.10488389  1.36108904  1.86983209 -1.39150098  2.18504658
#    1.79874163 -0.95279649  0.20060853  1.3004422  -0.32091429 -1.17184786
# ...

# %%
from sklearn.decomposition import PCA
# Using PCA i.e. Principal Component Analysis that is a diamensionallity reduction technique:

pca = PCA()
pca.fit_transform(X_scaled)
# Out:
# array([[ 3.24260243e+00, -1.01913458e+00, -2.37977770e-01,
#         -2.82888469e-01,  2.90611121e+00, -3.78209565e-01,
#          7.30289302e-01,  3.39045691e-01,  5.51421651e-01,
#          7.87923148e-01, -7.57922602e-02,  3.72212999e-01,
#          1.59292109e-01],
#        [-5.48575739e-01, -7.19339297e-01,  7.90026401e-02,
#         -2.69448833e-01,  3.87023496e-01, -5.95493499e-01,
#         -6.81731348e-01,  1.17875917e+00,  6.87947248e-01,
#         -7.16658138e-01,  1.42430244e-01,  2.62899622e-01,
#          4.04079049e-01],
#        [ 6.65185766e-02,  1.50494434e+00, -2.29264078e+00,
#         -1.93029173e+00, -6.65106413e-02,  6.57326236e-01,
#          1.32510540e+00,  1.34538450e+00, -8.20684811e-01,
#         -2.90107934e-01, -1.16826665e-01,  1.61682665e-01,
#         -2.62548013e-02],
#        [-4.00049419e-01, -1.38660262e+00, -1.22200846e+00,
#         -9.34983363e-02, -7.27356790e-01,  1.28517564e+00,
#         -3.95641540e-01,  1.39078159e-01, -1.06968021e+00,
# ...

# %%
# Using Scree Plot to identify best components:

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Principal Components')
plt.ylabel('Variance Covered')
plt.title('PCA')
plt.show()

# %%
pca = PCA(n_components=12)
new_pcomp = pca.fit_transform(X_scaled)
princi_comp = pd.DataFrame(new_pcomp)
princi_comp
# Out:
#           0         1         2         3         4         5         6   \
# 0   3.242602 -1.019135 -0.237978 -0.282888  2.906111 -0.378210  0.730289
# 1  -0.548576 -0.719339  0.079003 -0.269449  0.387023 -0.595493 -0.681731
# 2   0.066519  1.504944 -2.292641 -1.930292 -0.066511  0.657326  1.325105
# 3  -0.400049 -1.386603 -1.222008 -0.093498 -0.727357  1.285176 -0.395642
# 4   2.638610  0.344516 -0.877081 -1.064072 -0.597636 -0.368327 -1.346779
# 5   1.481709  4.899733 -1.430259  1.273954  0.457586  0.344165  0.580507
# 6  -0.381910  1.968179  0.098140  2.249631  1.074769  0.620543  0.439423
# 7  -2.319032  0.022204 -0.329228  2.318353  0.784937 -1.055885 -1.608986
# 8  -0.821636 -0.843829  1.776046 -0.217037  1.085270 -0.733862  0.351378
# 9   2.422612  0.842460 -0.128164  0.376767  0.979737  0.798868 -0.743474
# 10  0.903477  0.854811  0.649419  0.482579 -0.596677  1.102073  0.935627
# 11 -0.826525  1.899626  0.103307  0.724738 -1.626403 -1.771641  0.712834
# ...

# %%
pcols = princi_comp.columns

# %%
princi_comp.shape
# Out:
# (30, 12)

# %%
for i in princi_comp.columns:
    print(i ,':',princi_comp[i].skew())
# Out:
# 0 : 0.1641892526444594
# 1 : 0.5090033181616922
# 2 : 0.6520784269704929
# 3 : -0.11278525931371297
# 4 : 0.2850307541792181
# 5 : -0.12324303883594818
# 6 : 0.03598658365708494
# 7 : 0.19506127640567858
# 8 : 0.18374898334278508
# 9 : 0.2823595568343098
# 10 : 0.21508947292163838
# 11 : 0.3116201936807091

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(princi_comp[pcols],i) for i in range(princi_comp[pcols].shape[1])]
vif['features'] = princi_comp[pcols].columns
vif

# These number indicate that if vif value < 5 , 
# no multicolinearity problem exist
# Out:
#     vif  features
# 0   1.0         0
# 1   1.0         1
# 2   1.0         2
# 3   1.0         3
# 4   1.0         4
# 5   1.0         5
# 6   1.0         6
# 7   1.0         7
# 8   1.0         8
# 9   1.0         9
# 10  1.0        10
# 11  1.0        11

# %%
# Splitting our data to training data and testing data
# x_train,x_test,y_train,y_test

x_train,x_test,y_train,y_test = train_test_split(princi_comp,y,test_size=0.25,random_state=1)

# Here we are keeping training data as our scalled data and testing data as our label or target.

# %%
# MOdel instantiating and training

rm = LinearRegression()
rm.fit(x_train,y_train) 
# here we will pass training data
# Out:
# LinearRegression()

# %%
# Testing our model with Adjusted R2 Square: 

# on training data

rm.score(x_train,y_train)
# Out:
# 0.8408031825531846

# %%
# PLotting and visualizing

y_pred = rm.predict(x_test)

# %%
rm.score(x_test,y_test)
# Out:
# 0.6733837385523059

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Actual vs Model Predicted')
plt.show()

# %%
# Model Evaluation: MAE , MSE , RMSE

from sklearn.metrics import mean_absolute_error,mean_squared_error

mean_absolute_error(y_test,y_pred) # 4 % error
# Out:
# 4.390369619445153

# %%
mean_squared_error(y_test,y_pred) # lesser the better
# Out:
# 35.98902930826779

# %%
# RMSE
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5.99908570602786

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

lassocv = LassoCV(alphas = None , max_iter = 200, normalize = True)
lassocv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=200, normalize=True)

# %%
# Best alpha parameter
alpha = lassocv.alpha_ # Best alpha rate
alpha
# Out:
# 0.16111453736401898

# %%
# Now since we have the best parameter, lasso regression will be used:
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# i.e. when model is training it will learn at this speed 6....
# Out:
# Lasso(alpha=0.16111453736401898)

# %%
lasso_reg.score(x_train,y_train)
# Out:
# 0.8376604130318064

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.6812064762629759

# %%
# Ridge Method:

ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01),normalize = True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.score(x_train,y_train)
# Out:
# 0.8340175300588643

# %%
ridgecv.alpha_ # Best alpha rate
# Out:
# 0.09099999999999998

# %%
ridge_model = Ridge(alpha = ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
ridge_model.score(x_train,y_train)
# Out:
# 0.8407849631970915

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.6748044222392391

# %%
#model performance

print("MAE: ", metrics.mean_absolute_error(y_test, y_pred))
print("MSE: ", metrics.mean_squared_error(y_test, y_pred))
print("RMSE: ", metrics.mean_squared_error(y_test, y_pred, squared=False))
print("R2: ", metrics.r2_score(y_test, y_pred), "\n")
print("Score: ", ridge_model.score(x_test, y_test))
# Out:
# MAE:  4.390369619445153
# MSE:  35.98902930826779
# RMSE:  5.99908570602786
# R2:  0.6733837385523059
#
# Score:  0.6748044222392391

# %%
print(ridge_model.coef_)
print(f"{rm.intercept_:.2f}")
# Out:
# [-0.37603137  3.40892687  3.41154562 -1.92711051  4.34543144 -1.03282586
#   0.52904737 -0.20182665  4.52129606  1.3978679  -0.02055394  0.4607972 ]
# 80.60

# %%
# Using decision tree:

from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()

model.fit(x_train, y_train)

y_preddt = model.predict(x_test)

r2_score(y_test,y_preddt)
# Out:
# 0.02212138400453767

# %%
# Random forest:

from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor(n_estimators = 100)

regressor_rf.fit(x_train, y_train)

lr_normal_rf = regressor_rf.score(x_train, y_train)

lr_normal_rf
# Out:
# 0.8767562230394593

# %%
y_predrf = regressor_rf.predict(x_test)

lr_normal_rf_test = regressor_rf.score(x_test, y_test)

lr_normal_rf_test
# Out:
# 0.33755575723199094

# %%
mse_lr_normal_rf  = mean_absolute_error(y_test, y_predrf)

mse_lr_normal_rf
# Out:
# 6.984999999999999

# %%
# Model Evaluation: MAE , MSE , RMSE

from sklearn.metrics import mean_absolute_error,mean_squared_error

print("MAE: ", metrics.mean_absolute_error(y_test, y_predrf))
print("MSE: ", metrics.mean_squared_error(y_test, y_predrf))
print("RMSE: ", metrics.mean_squared_error(y_test, y_predrf, squared=False))
print("R2: ", metrics.r2_score(y_test, y_predrf), "\n")
print("Score: ", regressor_rf.score(x_test, y_predrf))
# Out:
# MAE:  6.984999999999999
# MSE:  72.993075
# RMSE:  8.543598480733982
# R2:  0.33755575723199094
#
# Score:  1.0

# %%
# Using Support vector regressor:

# Fit the model over the training data
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train, y_train)

y_predsvr = svr.predict(x_test)

r2_score(y_test,y_predsvr)
# Out:
# 0.08655071311844098

# %%
# Using XGBoost:

xgb_clf = xgb.XGBRegressor()
xgb_clf.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# Using XGBoost:

xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(x_train,y_train)

y_predx = xgb_reg.predict(x_test)

r2_score(y_test,y_predx)
# Out:
# 0.46696199688471973

# %%
# Model Evaluation: MAE , MSE , RMSE

from sklearn.metrics import mean_absolute_error,mean_squared_error

print("MAE: ", metrics.mean_absolute_error(y_test, y_predx))
print("MSE: ", metrics.mean_squared_error(y_test, y_predx))
print("RMSE: ", metrics.mean_squared_error(y_test, y_predx, squared=False))
print("R2: ", metrics.r2_score(y_test, y_predx), "\n")
print("Score: ", xgb_reg.score(x_test, y_predx))
# Out:
# MAE:  5.461477279663086
# MSE:  58.73412496826495
# RMSE:  7.663819215525961
# R2:  0.46696199688471973
#
# Score:  1.0

# %%
# Innitiate k neighbour Regressor:

from sklearn.neighbors import KNeighborsRegressor

params = {'n_neighbors':[2,3,4,5,6,7,8,9]}

knn = KNeighborsRegressor()

knnmodel = GridSearchCV(knn, params, cv=5)
knnmodel.fit(x_train,y_train)
knnmodel.best_params_
# Out:
# {'n_neighbors': 4}

# %%
knn_best = KNeighborsRegressor(n_neighbors = 4)
knn_best.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
y_predknn = knn_best.predict(x_test)

r2_score(y_test,y_predknn)
# Out:
# 0.682643221781055

# %%
from sklearn.ensemble import AdaBoostRegressor

regr = AdaBoostRegressor(random_state=0, n_estimators=100)
regr.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
y_predada = regr.predict(x_test)

# %%
r2_score(y_test,y_predada)
# Out:
# 0.28281492685727894

# %%
plt.scatter(y_test,y_predada)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Actual vs Model Predicted')
plt.show()

# %%
# Doing hyperparameter tuning of best models:

models = {'OLS': rm,
         'Lasso': lasso_reg,
         'Ridge': ridge_model}

def test(models, data, iterations = 100):
    results = {}
    for i in models:
        r2_train = []
        r2_test = []
        for j in range(iterations):
            x_train,x_test,y_train,y_test = train_test_split(princi_comp,y,test_size=0.25,random_state=1)

            r2_test.append(metrics.r2_score(y_test,
                                            models[i].fit(x_train, 
                                                         y_train).predict(x_test)))
            r2_train.append(metrics.r2_score(y_train, 
                                             models[i].fit(x_train, 
                                                          y_train).predict(x_train)))
        results[i] = [np.mean(r2_train), np.mean(r2_test)]
    return pd.DataFrame(results)

# %%
test(models, df)
# Out:
#         OLS     Lasso     Ridge
# 0  0.840803  0.837660  0.840785
# 1  0.673384  0.681206  0.674804

# %%
lasso_params = {'alpha':[0.02, 0.024, 0.025, 0.026, 0.03]}
ridge_params = {'alpha':[200, 230, 250,265, 270, 275, 290, 300, 500]}

models2 = {'OLS': rm,
           'Lasso': GridSearchCV(lasso_reg, 
                               param_grid=lasso_params).fit(x_train, y_train).best_estimator_,
           'Ridge': GridSearchCV(ridge_model, 
                               param_grid=ridge_params).fit(x_train, y_train).best_estimator_,}

# %%
test(models2, df)
# Out:
#         OLS     Lasso     Ridge
# 0  0.840803  0.840586  0.238656
# 1  0.673384  0.688684  0.212526

# %%
# Creating pipeline:

from sklearn.pipeline import Pipeline

# %%
"""Using Principal component analysis and scree plot we can confirm that we are left with 12 most important components or
features reponsible for predicting Wins value.

# Model instantiation and training:

After checking different models we can see that best result is obtained by using Linear regression and lasso regularization
technique.

# Sharing results found using Lasso regression model:

MAE:  4.740517672182099
MSE:  38.15445557317316
RMSE:  6.176929299674164
R2:  0.6537315432950819 

Score:  1.0"""
# Out:
# 'Using Principal component analysis and scree plot we can confirm that we are left with 12 most important components or\nfeatures reponsible for predicting Wins value.\n\n# Model instantiation and training:\n\nAfter checking different models we can see that best result is obtained by using Linear regression and lasso regularization\ntechnique.\n\n# Sharing results found using Lasso regression model:\n\nMAE:  4.740517672182099\nMSE:  38.15445557317316\nRMSE:  6.176929299674164\nR2:  0.6537315432950819 \n\nScore:  1.0'

# %%
pipe1 = Pipeline([('scaler',StandardScaler()),('pca',PCA(n_components=12)),('lasso_reg',LassoCV(alphas = [0.02, 0.024, 0.025, 0.026, 0.03] , max_iter = 100, normalize = True))])

pipe1.fit(x_train,y_train)

y_pred = pipe1.predict(x_test)

print("MAE: ", metrics.mean_absolute_error(y_test, y_pred))
print("MSE: ", metrics.mean_squared_error(y_test, y_pred))
print("RMSE: ", metrics.mean_squared_error(y_test, y_pred, squared=False))
print("R2: ", metrics.r2_score(y_test, y_pred), "\n")
print("Score: ", pipe1.score(x_test, y_pred))
# Out:
# MAE:  4.740517672182108
# MSE:  38.15445557317318
# RMSE:  6.176929299674166
# R2:  0.6537315432950818
#
# Score:  1.0
