# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r'C:\Users\User\Desktop\veeresh\Internship(test)\EXTRA/chrommedriver.exe')

# %%
driver.get("https://www.jagranjosh.com/")

# %%
Gk=driver.find_elements(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[9]/a')
Gk[0].click()

# %%
Pm=driver.find_elements(By.XPATH,'/html/body/div/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
Pm[0].click()

# %%
name=[]
born_dead=[]
term=[]
remarks=[]

# %%
name_tag=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td')
for i in name_tag:
    name.append(i.text.replace("\n","|"))
name
# Out:
# ['1.',
#  'Jawahar Lal Nehru',
#  '(1889–1964)',
#  '15 August 1947 to 27 May 1964|16 years, 286 days',
#  'The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  '2.',
#  'Gulzarilal Nanda (Acting)',
#  '(1898-1998)',
#  '27 May 1964 to 9 June 1964,|13 days',
#  'First acting PM of India',
#  '3.',
#  'Lal Bahadur Shastri',
#  '(1904–1966)',
#  '9 June 1964 to 11 January 1966|1 year, 216 days',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '4. ',
#  'Gulzari Lal Nanda  (Acting)',
#  '(1898-1998)',
#  '11 January 1966 to 24 January 1966|13 days',
#  '-',
#  '5.',
#  'Indira Gandhi',
#  '(1917–1984)',
#  '24 January 1966 to 24 March 1977|11 years, 59 days',
#  'First female Prime Minister of India',
#  '6.',
#  'Morarji Desai',
#  '(1896–1995)',
#  '24 March 1977 to  28 July 1979 |2 year, 126 days',
#  'Oldest to become PM (81 years old) and first to resign from office',
#  '7.',
# ...

# %%
names=[]
names.extend([name[1],name[6]])
names.extend([name[11],name[16]])
names.extend([name[21],name[26]])
names.extend([name[31],name[36]])
names.extend([name[41],name[46]])
names.extend([name[51],name[56]])
names.extend([name[61],name[66]])
names.extend([name[71],name[76]])
names.extend([name[81],name[86]])
names
# Out:
# ['Jawahar Lal Nehru',
#  'Gulzarilal Nanda (Acting)',
#  'Lal Bahadur Shastri',
#  'Gulzari Lal Nanda  (Acting)',
#  'Indira Gandhi',
#  'Morarji Desai',
#  'Charan Singh',
#  'Indira Gandhi',
#  'Rajiv Gandhi',
#  'V. P. Singh',
#  'Chandra Shekhar',
#  'P. V. Narasimha Rao',
#  'Atal Bihari Vajpayee',
#  'H. D. Deve Gowda',
#  'Inder Kumar Gujral',
#  'Atal Bihari Vajpayee',
#  'Manmohan Singh',
#  'Narendra Modi']

# %%
born_dead.extend([name[2],name[7]])
born_dead.extend([name[12],name[17]])
born_dead.extend([name[22],name[27]])
born_dead.extend([name[32],name[37]])
born_dead.extend([name[42],name[47]])
born_dead.extend([name[52],name[57]])
born_dead.extend([name[62],name[67]])
born_dead.extend([name[72],name[77]])
born_dead.extend([name[82],name[87]])
born_dead
# Out:
# ['(1889–1964)',
#  '(1898-1998)',
#  '(1904–1966)',
#  '(1898-1998)',
#  '(1917–1984)',
#  '(1896–1995)',
#  '(1902–1987)',
#  '(1917–1984)',
#  '(1944–1991)',
#  '(1931–2008)',
#  '(1927–2007)',
#  '(1921–2004)',
#  '(1924- 2018)',
#  '(born 1933)',
#  '(1919–2012)',
#  '(1924-2018)',
#  '(born 1932)',
#  '(born 1950)']

# %%
term.extend([name[3],name[8]])
term.extend([name[13],name[18]])
term.extend([name[23],name[28]])
term.extend([name[33],name[38]])
term.extend([name[43],name[48]])
term.extend([name[53],name[58]])
term.extend([name[63],name[68]])
term.extend([name[73],name[78]])
term.extend([name[83],name[88]])
term
# Out:
# ['15 August 1947 to 27 May 1964|16 years, 286 days',
#  '27 May 1964 to 9 June 1964,|13 days',
#  '9 June 1964 to 11 January 1966|1 year, 216 days',
#  '11 January 1966 to 24 January 1966|13 days',
#  '24 January 1966 to 24 March 1977|11 years, 59 days',
#  '24 March 1977 to  28 July 1979 |2 year, 126 days',
#  '28 July 1979 to 14 January 1980|170 days',
#  '14 January 1980 to 31 October 1984|4 years, 291 days',
#  '31 October 1984 to 2 December 1989|5 years, 32 days',
#  '2 December 1989 to 10 November 1990|343 days',
#  '10 November 1990 to 21 June 1991|223 days',
#  '21 June 1991 to 16 May 1996|4 years, 330 days',
#  '16 May 1996 to 1 June 1996|16 days',
#  '1 June 1996 to 21 April 1997|324 days',
#  '21 April 1997 to 19 March 1998 |332 days',
#  '19 March 1998 to 22 May 2004 |6 years, 64 days',
#  '22 May 2004 to 26 May 2014   |10 years, 4 days',
#  '26 May 2014 - Present']

# %%
remarks.extend([name[4],name[9]])
remarks.extend([name[14],name[19]])
remarks.extend([name[24],name[29]])
remarks.extend([name[34],name[39]])
remarks.extend([name[44],name[49]])
remarks.extend([name[54],name[59]])
remarks.extend([name[64],name[69]])
remarks.extend([name[74],name[79]])
remarks.extend([name[84],name[89]])
remarks
# Out:
# ['The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  'First acting PM of India',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '-',
#  'First female Prime Minister of India',
#  'Oldest to become PM (81 years old) and first to resign from office',
#  'Only PM who did not face the Parliament',
#  'The first lady who served as PM for the second term',
#  'Youngest to become PM (40 years old)',
#  'First PM to step down after a vote of no confidence',
#  'He belongs to  Samajwadi Janata Party',
#  'First PM from south India',
#  'PM for shortest tenure',
#  'He belongs to  Janata Dal',
#  '------',
#  ' The first non-congress PM who completed a full term as PM',
#  ' First Sikh PM',
#  '4th Prime Minister of India who served two consecutive tenures']

# %%
len(name),len(names),len(born_dead),len(term),len(remarks)
# Out:
# (94, 18, 18, 18, 18)

# %%
df=pd.DataFrame({'Name':names,'Born-Dead':born_dead,'Term of office':term,'Remarks':remarks})
df
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of office  \
# ...
